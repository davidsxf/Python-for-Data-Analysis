# %%
# 从excel表读入数据到dataframe
import pandas as pd

feed = pd.read_excel('feed.xls')

# %%
feed.groupby('w_rang').plot(x='temper',y='coe')
# Out:
# w_rang
# 1000-1500    Axes(0.125,0.11;0.775x0.77)
# 200-500      Axes(0.125,0.11;0.775x0.77)
# 50-200       Axes(0.125,0.11;0.775x0.77)
# 500-1000     Axes(0.125,0.11;0.775x0.77)
# dtype: object

# %%
feed.plot(x='temper',y='coe')
# Out:
# <Axes: xlabel='temper'>

# %%
feed.groupby('temper').plot(x='w_rang',y='coe')
# Out:
# temper
# 14    Axes(0.125,0.11;0.775x0.77)
# 19    Axes(0.125,0.11;0.775x0.77)
# 23    Axes(0.125,0.11;0.775x0.77)
# 28    Axes(0.125,0.11;0.775x0.77)
# 30    Axes(0.125,0.11;0.775x0.77)
# 40    Axes(0.125,0.11;0.775x0.77)
# dtype: object
